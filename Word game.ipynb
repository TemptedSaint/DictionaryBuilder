# %%
import numpy as np
import pandas as pd
from numpy import genfromtxt
from collections import Counter
from io import BytesIO
import random as rand

def filecompleter(arr,file):
    count = 0
    while(count<len(arr)):
        temp=arr[count].index('/')
        file.write(arr[count][:temp])
        if(count < len(arr)-1):
            file.write('\n')
        count+=1

file3 = open(r"3n.txt", "r")
file4 = open(r"4n.txt", "r")
file5 = open(r"5n.txt", "r")
file6 = open(r"6n.txt", "r")
file7 = open(r"7n.txt", "r")
file8 = open(r"8n.txt", "r")

filea = open("3.csv","w")
fileb = open("4.csv","w")
filec = open("5.csv","w")
filed = open("6.csv","w")
filee = open("7.csv","w")
filef = open("8.csv","w")

three = file3.read().split('\n')
four = file4.read().split('\n')
five = file5.read().split('\n')
six = file6.read().split('\n')
seven = file7.read().split('\n')
eight = file8.read().split('\n')

filecompleter(three,filea)
filecompleter(four,fileb)
filecompleter(five,filec)
filecompleter(six,filed)
filecompleter(seven,filee)
filecompleter(eight,filef)

filea.close()
fileb.close()
filec.close()
filed.close()
filee.close()
filef.close()

# %%
import numpy as np
import pandas as pd
from numpy import genfromtxt
from collections import Counter
from io import BytesIO

fileR = open("region1.csv","w")

easy1 = [26,32]
easy2 = [36,48]
med1 = [49,65]
med2 = [50,80]
hard1 = [133,243]
hard2 = [244,458]

def reader(file1, rang):
    random=random.randint(rang[0],rang[1])

# %%
import numpy as np
import pandas as pd
from numpy import genfromtxt
from collections import Counter
from io import BytesIO
import random

easy1 = [26,42]
easy2 = [36,55]
med1 = [49,65]
med2 = [50,99]
hard1 = [133,243]
hard2 = [244,458]

file5 = open(r"5Man.csv", "r")
file6 = open(r"6Man.csv", "r")
file7 = open(r"7Man.csv", "r")
file8 = open(r"8Man.csv", "r")

arr5 = np.genfromtxt('5Man.csv', delimiter=",",dtype=int)
arr6 = np.genfromtxt('6Man.csv', delimiter=",",dtype=int)
arr7 = np.genfromtxt('7Man.csv', delimiter=",",dtype=int)
arr8 = np.genfromtxt('8Man.csv', delimiter=",",dtype=int)

def reader(arr,words, rang, modifier,FileRegion,NoW):
    rando= random.randint(0,1)
    temp = arr
    FileRegion.write('\"')
    for x in range(0,NoW):
        rando=random.randint(rang[0],(rang[1]+modifier))
        truth = temp.shape
        killme=False
        while(killme==False):
            randles=random.randint(0,(truth[0]-1))
            if(temp[randles,0] == rando):
                killme = True
                FileRegion.write(str(words))
                FileRegion.write(',')
                FileRegion.write(str(randles))
                FileRegion.write(',')
    
    FileRegion.write('\",')
    
def regionGenerator(modifier,FileRegion):
    for z in range(0,3):
        FileRegion.write('!')
        FileRegion.write(str(z))
        FileRegion.write('!')
        FileRegion.write('\n')
        for x in range(0,25):
            rando= random.randint(1,2)
            if(x<5):
                NoW = 3
            elif(x<14):
                NoW = 4
            elif(x==14):
                NoW = 1
            elif(x<24):
                NoW = 5
            else:
                NoW = 1
                
            if(z==0):
                fileRef = rando+4
                eval('reader(arr'+str(fileRef)+','+str(fileRef)+',easy'+str(rando)+',modifier,FileRegion,NoW)')
            elif(z==1):
                fileRef = rando+5
                eval('reader(arr'+str(fileRef)+','+str(fileRef)+',med'+str(rando)+',modifier,FileRegion,NoW)')
            else:
                fileRef = rando+6
                eval('reader(arr'+str(fileRef)+','+str(fileRef)+',hard'+str(rando)+',modifier,FileRegion,NoW)')
        FileRegion.write('\n')
region2 = open("Region1.txt", "w")
regionGenerator((0),region2)
region2.close()
region2 = open("Region2.txt", "w")
regionGenerator((0),region2)
region2.close()
region2 = open("Region3.txt", "w")
regionGenerator((0),region2)
region2.close()

# %%
file5 = open(r"5n.txt", "r")
file6 = open(r"6n.txt", "r")
file7 = open(r"7n.txt", "r")
file8 = open(r"8n.txt", "r")
filec = open("5.txt","w")
filed = open("6.txt","w")
filee = open("7.txt","w")
filef = open("8.txt","w")
filei = open(r"5.csv", "r")
fileii = open(r"6.csv", "r")
fileiii = open(r"7.csv", "r")
fileiv = open(r"8.csv", "r")
five = file5.read().split('\n')
six = file6.read().split('\n')
seven = file7.read().split('\n')
eight = file8.read().split('\n')
fivea = filei.read().split('\n')
sixb = fileii.read().split('\n')
sevenc = fileiii.read().split('\n')
eightd = fileiv.read().split('\n')
for x in range(0,len(five)):
    filec.write(fivea[x])
    filec.write(',')
    filec.write(five[x])
    filec.write('\n')
for x in range(0,len(six)):
    filed.write(sixb[x])
    filed.write(',')
    filed.write(six[x])
    filed.write('\n')
for x in range(0,len(seven)):
    filee.write(sevenc[x])
    filee.write(',')
    filee.write(seven[x])
    filee.write('\n')
for x in range(0,len(eight)):
    filef.write(eightd[x])
    filef.write(',')
    filef.write(eight[x])
    filef.write('\n')
filec.close()
filed.close()
filee.close()
filef.close()
file5.close()
file6.close()
file7.close()
file8.close()

# %%
import numpy as np

filec = open(r"5.txt","r")
filed = open(r"6.txt","r")
filee = open(r"7.txt","r")
filef = open(r"8.txt","r")

five = filec.read().split('\n')
six = filed.read().split('\n')
seven = filee.read().split('\n')
eight = filef.read().split('\n')
fivearr=np.empty([len(five),2],dtype=int)
sixarr=np.empty([len(six),2],dtype=int)
sevenarr=np.empty([len(seven),2],dtype=int)
eightarr=np.empty([len(eight),2],dtype=int)
for x in range(0,(len(five)-1)):
    temp=five[x].index(',')
    print(five[x][:temp])
    fivearr[x,0]=int(five[x][:temp])
    fivearr[x,1]=x
for x in range(0,(len(six)-1)):
    temp=six[x].index(',')
    sixarr[x,0]=int(six[x][:temp])
    sixarr[x,1]=x
for x in range(0,(len(seven)-1)):
    temp=seven[x].index(',')
    sevenarr[x,0]=int(seven[x][:temp])
    sevenarr[x,1]=x
for x in range(0,(len(eight)-1)):
    temp=eight[x].index(',')
    eightarr[x,0]=int(eight[x][:temp])
    eightarr[x,1]=x
np.sort(fivearr, axis=0)
np.sort(sixarr, axis=0)
np.sort(sevenarr, axis=0)
np.sort(eightarr, axis=0)
print(fivearr[205,0])
np.savetxt("5Man.csv", fivearr, delimiter=",",fmt="%i")
np.savetxt("6Man.csv", sixarr, delimiter=",",fmt="%i")
np.savetxt("7Man.csv", sevenarr, delimiter=",",fmt="%i")
np.savetxt("8Man.csv", eightarr, delimiter=",",fmt="%i")
filec.close()
filed.close()
filee.close()
filef.close()

# %%
import numpy as np
test = np.genfromtxt("5Man.csv", delimiter=",",dtype=int)
print(test[205,0])

# %%
file = open("wordHolder.txt", "w")
for x in range(0,3):
    file.write('{')
    for y in range(0,25):
        file.write('\"\",')
    file.write('},')
file.close()

# %%
file = open("saveHolder.txt", "w")
for x in range(0,3):
    file.write('{')
    for y in range(0,25):
        file.write('null,')
    file.write('},')
file.close()

# %%
file = open(r"8n.txt", "r")
file2 = open("8cs.txt", "w")
five = file.read().split('\n')
file2.write('{')
for x in range(0,len(five)):
    file2.write('\"')
    file2.write(five[x])
    file2.write('\",')
file2.write('}')
file.close()
file2.close()

# %%
import numpy as np

filea = open("5c.txt","w")
fileb = open("6c.txt","w")
filec = open("7c.txt","w")
filed = open("8c.txt","w")

arr5 = np.genfromtxt('5Man.csv', delimiter=",",dtype=int)
arr6 = np.genfromtxt('6Man.csv', delimiter=",",dtype=int)
arr7 = np.genfromtxt('7Man.csv', delimiter=",",dtype=int)
arr8 = np.genfromtxt('8Man.csv', delimiter=",",dtype=int)

count5 = arr5.shape
count6 = arr6.shape
count7 = arr7.shape
count8 = arr8.shape

for x in range(0,(count5[0]-1)):
    filea.write(str(arr5[x,0]))
    filea.write(',')
filea.close()

for x in range(0,(count6[0]-1)):
    fileb.write(str(arr6[x,0]))
    fileb.write(',')
fileb.close()

for x in range(0,(count7[0]-1)):
    filec.write(str(arr7[x,0]))
    filec.write(',')
filec.close()

for x in range(0,(count8[0]-1)):
    filed.write(str(arr8[x,0]))
    filed.write(',')
filed.close()

# %%
import numpy as np

filea = open("5count.txt","w")
fileb = open("6count.txt","w")
filec = open("7count.txt","w")
filed = open("8count.txt","w")

arr5 = np.genfromtxt('5c.txt', delimiter=",",dtype=int)
arr6 = np.genfromtxt('6c.txt', delimiter=",",dtype=int)
arr7 = np.genfromtxt('7c.txt', delimiter=",",dtype=int)
arr8 = np.genfromtxt('8c.txt', delimiter=",",dtype=int)

count1 = np.bincount(arr5)
count2 = np.bincount(arr6)
count3 = np.bincount(arr7)
count4 = np.bincount(arr8)

result1 = np.nonzero(count1)[0]
result2 = np.nonzero(count2)[0]
result3 = np.nonzero(count3)[0]
result4 = np.nonzero(count4)[0]

index1 = np.empty(result1.shape, dtype=int)
index2 = np.empty(result2.shape,dtype=int)
index3 = np.empty(result3.shape,dtype=int)
index4 = np.empty(result4.shape,dtype=int)

shape1 = result1.shape
shape2 = result2.shape
shape3 = result3.shape
shape4 = result4.shape

for x in range(0,(shape1[0]-1)):
    temp = np.where(arr5 == result1[x])
    np.put(index1,[x], temp[0])
for x in range(0,(shape2[0]-1)):
    temp = np.where(arr6 == result2[x])
    np.put(index2,[x], temp[0])
for x in range(0,(shape3[0]-1)):
    temp = np.where(arr7 == result3[x])
    np.put(index3,[x], temp[0])
for x in range(0,(shape4[0]-1)):
    temp = np.where(arr8 == result4[x])
    np.put(index4,[x], temp[0])

subt1 = np.vstack((count1[result1],index1)).T
subt2 = np.vstack((count2[result2],index2)).T
subt3 = np.vstack((count3[result3],index3)).T
subt4 = np.vstack((count4[result4],index4)).T

subc1 = subt1.shape
subc2 = subt2.shape
subc3 = subt3.shape
subc4 = subt4.shape

for x in range(0,(subc1[0]-1)):
    filea.write('{')
    '''filea.write(str(subt1[x,0])1
    filea.write(',')'''
    filea.write(str(subt1[x,0]))
    filea.write(',')
    filea.write(str(subt1[x,1]))
    filea.write('}')
    filea.write(',')

for x in range(0,(subc2[0]-1)):
    fileb.write('{')
    '''fileb.write(str(subt2[x,0]))
    fileb.write(',')'''
    fileb.write(str(subt2[x,0]))
    fileb.write(',')
    fileb.write(str(subt2[x,1]))
    fileb.write('}')
    fileb.write(',')

for x in range(0,(subc3[0]-1)):
    filec.write('{')
    '''filec.write(str(subt3[x,0]))
    filec.write(',')'''
    filec.write(str(subt3[x,0]))
    filec.write(',')
    filec.write(str(subt3[x,1]))
    filec.write('}')
    filec.write(',')

for x in range(0,(subc4[0]-1)):
    filed.write('{')
    '''filed.write(str(subt4[x,0]))
    filed.write(',')'''
    filed.write(str(subt4[x,0]))
    filed.write(',')
    filed.write(str(subt4[x,1]))
    filed.write('}')
    filed.write(',')

filea.close()
fileb.close()
filec.close()
filed.close()
'''
filea = open("5fix.txt","w")
fileb = open("6fix.txt","w")
filec = open("7fix.txt","w")
filed = open("8fix.txt","w")

for x in range(0,(subc1[0]-1)):
    filea.write(str(subt1[x,0]))
    filea.write(',')

for x in range(0,(subc2[0]-1)):
    fileb.write(str(subt2[x,0]))
    fileb.write(',')

for x in range(0,(subc3[0]-1)):
    filec.write(str(subt3[x,0]))
    filec.write(',')

for x in range(0,(subc4[0]-1)):
    filed.write(str(subt4[x,0]))
    filed.write(',')
    
filea.close()
fileb.close()
filec.close()
filed.close()
'''
# Out:
# '\nfilea = open("5fix.txt","w")\nfileb = open("6fix.txt","w")\nfilec = open("7fix.txt","w")\nfiled = open("8fix.txt","w")\n\nfor x in range(0,(subc1[0]-1)):\n    filea.write(str(subt1[x,0]))\n    filea.write(\',\')\n\nfor x in range(0,(subc2[0]-1)):\n    fileb.write(str(subt2[x,0]))\n    fileb.write(\',\')\n\nfor x in range(0,(subc3[0]-1)):\n    filec.write(str(subt3[x,0]))\n    filec.write(\',\')\n\nfor x in range(0,(subc4[0]-1)):\n    filed.write(str(subt4[x,0]))\n    filed.write(\',\')\n    \nfilea.close()\nfileb.close()\nfilec.close()\nfiled.close()\n'
